# %%
import os
import pandas as pd
from rdkit import Chem
import sys
import matplotlib.pyplot as plt


DATAPATH = "../data"
SMICOL = "smiles"
INCHICOL = "inchikey"
ACTCOL = "activity"

# Add the src directory to the system path
sys.path.append(os.path.abspath("../../src"))

# %%
from plot import plot_scatter_from_csv

# %% [markdown]
# ## Model Bias
# ### This notebook checks for the model bias of the predictions of the models against the validations csv file [here](https://github.com/Richiio/model-validations/blob/main/data/Validations.csv)

# %% [markdown]
# ## eos2ta5

# %%
file_path = os.path.join(DATAPATH, "bias_predictions", "bias_predictions_eos2ta5.csv")
column_name = 'probability'
plot_scatter_from_csv(file_path, column_name)

# %% [markdown]
# ## eos4tcc

# %%
file_path = os.path.join(DATAPATH, "bias_predictions", "bias_predictions_eos4tcc.csv")
column_name = 'score'
plot_scatter_from_csv(file_path, column_name)

# %% [markdown]
# ## eos30gr

# %%
file_path = os.path.join(DATAPATH, "bias_predictions", "bias_predictions_eos30gr.csv")
column_name = 'activity10'
plot_scatter_from_csv(file_path, column_name)

# %% [markdown]
# ## eos43at

# %%
file_path = os.path.join(DATAPATH, "bias_predictions", "bias_predictions_eos43at.csv")
column_name = 'pic50'
plot_scatter_from_csv(file_path, column_name)

# %% [markdown]
# ## eos30f3

# %%
file_path = os.path.join(DATAPATH, "bias_predictions", "bias_predictions_eos30f3.csv")
column_name = 'activity'
plot_scatter_from_csv(file_path, column_name)
