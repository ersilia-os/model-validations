# %%
import pandas as pd
import matplotlib.pyplot as plt

DATAPATH = "../cytotox/data/model_prediction_output"

# %%
eos3le9 = pd.read_csv(os.path.join(DATAPATH, "eos3le9_output.csv"))
eos3le9.head()
# Out:
#    HepG2_IC50_72h_5uM  HepG2_IC50_72h_10uM
# 0            0.026933             0.435868
# 1            0.027204             0.259903
# 2            0.065556             0.547839
# 3            0.035275             0.615741
# 4            0.017164             0.367035

# %%
# Generate x values (indices)
x = range(len(eos3le9))
plt.scatter(x, eos3le9['HepG2_IC50_72h_5uM'])
plt.xlabel('Index')
plt.ylabel('HepG2_IC50_72h_5uM')
plt.title('Model_eos3le9_HepG2_IC50_72h_5uM')
plt.show()

# %%
# Generate x values (indices)
x = range(len(eos3le9))
plt.scatter(x, eos3le9['HepG2_IC50_72h_10uM'])
plt.xlabel('Index')
plt.ylabel('HepG2_IC50_72h_10uM')
plt.title('eos3le9_HepG2_IC50_72h_10uM')
plt.show()

# %%
eos2fy6 = pd.read_csv(os.path.join(DATAPATH, "eos2fy6_output.csv"))
eos2fy6.head()
# Out:
#    HepG2_toxicity_prob_predict
# 0                     0.215736
# 1                     0.173825
# 2                     0.272437
# 3                     0.357127
# 4                     0.382352

# %%
# Generate x values (indices)
x = range(len(eos2fy6))
plt.scatter(x, eos2fy6['HepG2_toxicity_prob_predict'])
plt.xlabel('Index')
plt.ylabel('HepG2_toxicity_prob_predict')
plt.title('Model_eos2fy6')
plt.show()

# %%
eos69p9 = pd.read_csv(os.path.join(DATAPATH, "eos69p9_output.csv"))
eos69p9.head()
# Out:
#                            key  \
# 0  OCFACRWFEFGYDB-UHFFFAOYSA-N
# 1  HMBAGIWVHSMZGN-UHFFFAOYSA-N
# 2  LYNBJSJVJXRVTC-BZSNNMDCSA-N
# 3  OZLHJBSTXWDJKT-UHFFFAOYSA-N
# 4  YUSCAAHQWLTSSG-IBGZPJMESA-N
#
#                                                input  SR-ATAD5     NR-ER  \
# 0                        OC1=CC=C(O)C(C2CCCCCCC2)=C1  0.270848  0.097965
# 1                    CC1(C)NC(=O)N(CCC2=CC=CC=C2)C1O  0.102558  0.018865
# 2  N[C@@H](CC1=CC=C(O)C=C1)C(=O)N[C@H]1CSSC[C@@H]...  0.150545  0.042752
# 3  CCCCN(C)C(=O)C1=CC=C2C(=C1)C1=C(N2S(=O)(=O)CC)...  0.083193  0.023695
# 4  CN(CCCN1C(=O)[C@@H]2CC3=CC=CC=C3CN2C1=O)C1=CC=...  0.135802  0.040547
#
#    NR-AR-LBD  NR-Aromatase    SR-MMP    SR-p53    SR-HSE     NR-AR  \
# 0   0.010406      0.019060  0.100497  0.069339  0.653250  0.047883
# 1   0.016949      0.018285  0.039282  0.010154  0.011745  0.052045
# 2   0.066081      0.019216  0.076271  0.015916  0.008417  0.203111
# ...

# %%
eos7kpb = pd.read_csv(os.path.join(DATAPATH, "eos7kpb_output.csv"))
eos7kpb.head()
# Out:
#                            key  \
# 0  OCFACRWFEFGYDB-UHFFFAOYSA-N
# 1  HMBAGIWVHSMZGN-UHFFFAOYSA-N
# 2  LYNBJSJVJXRVTC-BZSNNMDCSA-N
# 3  OZLHJBSTXWDJKT-UHFFFAOYSA-N
# 4  YUSCAAHQWLTSSG-IBGZPJMESA-N
#
#                                                input   pf_nf54     pf_k1  \
# 0                        OC1=CC=C(O)C(C2CCCCCCC2)=C1  0.002079  0.142397
# 1                    CC1(C)NC(=O)N(CCC2=CC=CC=C2)C1O  0.001627  0.146196
# 2  N[C@@H](CC1=CC=C(O)C=C1)C(=O)N[C@H]1CSSC[C@@H]...  0.003292  0.137918
# 3  CCCCN(C)C(=O)C1=CC=C2C(=C1)C1=C(N2S(=O)(=O)CC)...  0.123341  0.167524
# 4  CN(CCCN1C(=O)[C@@H]2CC3=CC=CC=C3CN2C1=O)C1=CC=...  0.001100  0.128945
#
#         mtb       cho     hepg2   clint_h   clint_m   clint_r  ...  \
# 0  0.152719  0.094309  0.465928  0.517115  0.577185  0.575446  ...
# 1  0.019858  0.087238  0.351114  0.436182  0.479685  0.510852  ...
# 2  0.006509  0.159355  0.232103  0.434412  0.509352  0.519899  ...
# ...

# %%
eos92sw = pd.read_csv(os.path.join(DATAPATH, "eos92sw_output.csv"))
eos92sw.head()
# Out:
#                            key  \
# 0  OCFACRWFEFGYDB-UHFFFAOYSA-N
# 1  HMBAGIWVHSMZGN-UHFFFAOYSA-N
# 2  LYNBJSJVJXRVTC-BZSNNMDCSA-N
# 3  OZLHJBSTXWDJKT-UHFFFAOYSA-N
# 4  YUSCAAHQWLTSSG-IBGZPJMESA-N
#
#                                                input  Tox-score   SAscore
# 0                        OC1=CC=C(O)C(C2CCCCCCC2)=C1   0.683635  0.383289
# 1                    CC1(C)NC(=O)N(CCC2=CC=CC=C2)C1O   0.607879  0.136892
# 2  N[C@@H](CC1=CC=C(O)C=C1)C(=O)N[C@H]1CSSC[C@@H]...   0.572902  0.018813
# 3  CCCCN(C)C(=O)C1=CC=C2C(=C1)C1=C(N2S(=O)(=O)CC)...   0.436973  0.162351
# 4  CN(CCCN1C(=O)[C@@H]2CC3=CC=CC=C3CN2C1=O)C1=CC=...   0.545017  0.170426

# %%
# Generate x values (indices)
x = range(len(data))
plt.scatter(x, data5['Tox-score'])
plt.xlabel('Index')
plt.ylabel('Tox-score')
plt.title('eos92sw_toxscore')
plt.show()

# %%
eos9yy1 = pd.read_csv(os.path.join(DATAPATH, "eos9yy1_output.csv"))
eos9yy1.head()
# Out:
#                            key  \
# 0  OCFACRWFEFGYDB-UHFFFAOYSA-N
# 1  HMBAGIWVHSMZGN-UHFFFAOYSA-N
# 2  LYNBJSJVJXRVTC-BZSNNMDCSA-N
# 3  OZLHJBSTXWDJKT-UHFFFAOYSA-N
# 4  YUSCAAHQWLTSSG-IBGZPJMESA-N
#
#                                                input  hlcs_proba1
# 0                        OC1=CC=C(O)C(C2CCCCCCC2)=C1        0.403
# 1                    CC1(C)NC(=O)N(CCC2=CC=CC=C2)C1O        0.213
# 2  N[C@@H](CC1=CC=C(O)C=C1)C(=O)N[C@H]1CSSC[C@@H]...        0.313
# 3  CCCCN(C)C(=O)C1=CC=C2C(=C1)C1=C(N2S(=O)(=O)CC)...        0.413
# 4  CN(CCCN1C(=O)[C@@H]2CC3=CC=CC=C3CN2C1=O)C1=CC=...        0.242

# %%
# Generate x values (indices)
x = range(len(data))
plt.scatter(x, data6['hlcs_proba1'])
plt.xlabel('Index')
plt.ylabel('hlcs_proba1')
plt.title('eos9yy1_hlcs')
plt.show()
